# %% [markdown]
# # Bienvenidos a Pandas

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
data = {
    'manzanas' : [3,2,1,0],
    'naranjas' : [0,1,2,3],
    'kiwis' :    [0,1,5,8]
}

# %%
df = pd.DataFrame(data)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df = pd.DataFrame(data)
#       2 df
#
# NameError: name 'pd' is not defined

# %%
manzanas = df['manzanas']
manzanas
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 manzanas = df['manzanas']
#       2 manzanas
#
# NameError: name 'df' is not defined

# %%
df.naranjas
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df.naranjas
#
# NameError: name 'df' is not defined

# %%
list(df.naranjas)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 list(df.naranjas)
#
# NameError: name 'df' is not defined

# %% [markdown]
# # Anális del .csv

# %%
df = pd.read_csv('data/imdb.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df = pd.read_csv('data/imdb.csv')
#
# NameError: name 'pd' is not defined

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
df.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df.head(10)
#
# NameError: name 'df' is not defined

# %%
df.tail(3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df.tail(3)
#
# NameError: name 'df' is not defined

# %%
df.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df.columns
#
# NameError: name 'df' is not defined

# %%
df.Rank.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df.Rank.head()
#
# NameError: name 'df' is not defined

# %%
df.rename(columns= {'Revenue (Millions)':'Revenue_Millions'}, inplace=True)
df.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df.rename(columns= {'Revenue (Millions)':'Revenue_Millions'}, inplace=True)
#       2 df.columns
#
# NameError: name 'df' is not defined

# %%
df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 df.info()
#
# NameError: name 'df' is not defined

# %%
df.Revenue_Millions.isna().any()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df.Revenue_Millions.isna().any()
#
# NameError: name 'df' is not defined

# %%
df.Metascore.isna()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 df.Metascore.isna()
#
# NameError: name 'df' is not defined

# %%
print("No. de NA en Metascore:", df.Metascore.isna().sum())
print("No. de NA en Rank:", df.Rank.isna().sum())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 print("No. de NA en Metascore:", df.Metascore.isna().sum())
#       2 print("No. de NA en Rank:", df.Rank.isna().sum())
#
# NameError: name 'df' is not defined

# %%
df.Rank.isna()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: Rank, Length: 1000, dtype: bool

# %%
df = df.dropna()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 df = df.dropna()
#
# NameError: name 'df' is not defined

# %%
df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 df.info()
#
# NameError: name 'df' is not defined

# %%
df.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 df.describe()
#
# NameError: name 'df' is not defined

# %%
x = df.Rating
type(x)

x.mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 x = df.Rating
#       2 type(x)
#       3
#       4 x.mean()
#
# NameError: name 'df' is not defined

# %%
import numpy as np 
np.mean(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 2
#       1 import numpy as np
# ----> 2 np.mean(x)
#
# NameError: name 'x' is not defined

# %%
df['Rating'].unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 df['Rating'].unique()
#
# NameError: name 'df' is not defined

# %%
np.sort(df['Rating'].unique())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 np.sort(df['Rating'].unique())
#
# NameError: name 'df' is not defined

# %% [markdown]
# # Filtro

# %%
df[df.Rating > 8].head(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 df[df.Rating > 8].head(2)
#
# NameError: name 'df' is not defined

# %%
df.Rating.value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 df.Rating.value_counts()
#
# NameError: name 'df' is not defined

# %%
counts = df.Rating.value_counts()

counts.index
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 counts = df.Rating.value_counts()
#       2
#       3 counts.index
#
# NameError: name 'df' is not defined

# %%
counts.values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 counts.values
#
# NameError: name 'counts' is not defined

# %%
counts_df = pd.DataFrame({'calif': counts.index, 'frequency': counts.values})
counts_df.head(4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 counts_df = pd.DataFrame({'calif': counts.index, 'frequency': counts.values})
#       2 counts_df.head(4)
#
# NameError: name 'pd' is not defined

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.barplot(
    data=counts_df,
    x='calif',
    y='frequency'
)

plt.title('Frecuencia de Calificaciones')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 import seaborn as sns
#       2 import matplotlib.pyplot as plt
#       3
#       4 sns.barplot(
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
# kde=True añade una curva de densidad suave sobre las barras
sns.histplot(data=df, x='Rating', kde=True, bins=25, color='skyblue')

plt.title('Distribución de las Calificaciones de Películas (Rating)')
plt.xlabel('Calificación')
plt.ylabel('Cantidad de Películas')
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 import seaborn as sns
#       2 import matplotlib.pyplot as plt
#       3
#       4 plt.figure(figsize=(10, 6))
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
# Graficamos Rating en el eje X y Revenue_Millions en el eje Y
sns.scatterplot(data=df, x='Rating', y='Revenue_Millions', alpha=0.6, color='coral', edgecolor='black')

plt.title('Relación entre Calificación e Ingresos (Revenue)')
plt.xlabel('Calificación (Rating)')
plt.ylabel('Ingresos en Millones (Revenue Millions)')
plt.grid(True, linestyle='--', alpha=0.4)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 import seaborn as sns
#       2 import matplotlib.pyplot as plt
#       3
#       4 plt.figure(figsize=(10, 6))
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.kdeplot(data=df, x='Runtime (Minutes)', fill=True, color='darkviolet', alpha=0.4)

plt.title('Distribución Suavizada de la Duración de las Películas')
plt.xlabel('Duración en Minutos (Runtime)')
plt.ylabel('Densidad de Probabilidad')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 import seaborn as sns
#       2 import matplotlib.pyplot as plt
#       3
#       4 plt.figure(figsize=(10, 6))
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
# Filtramos los últimos 3 años para comparar su distribución
df_reciente = df[df['Year'].isin([2014, 2015, 2016])]

sns.violinplot(data=df_reciente, x='Year', y='Runtime (Minutes)', palette='pastel')

plt.title('Distribución de Duración de Películas en Años Recientes')
plt.xlabel('Año')
plt.ylabel('Duración en Minutos')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 import seaborn as sns
#       2 import matplotlib.pyplot as plt
#       3
#       4 plt.figure(figsize=(12, 6))
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
# Seleccionamos únicamente variables numéricas relevantes
columnas_numericas = df[['Rating', 'Votes', 'Revenue_Millions', 'Metascore', 'Runtime (Minutes)']]
matriz_corr = columnas_numericas.corr()

# annot=True muestra los números dentro de los cuadros
sns.heatmap(matriz_corr, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)

plt.title('Mapa de Calor de Correlaciones Numéricas')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 import seaborn as sns
#       2 import matplotlib.pyplot as plt
#       3
#       4 plt.figure(figsize=(8, 6))
#
# ModuleNotFoundError: No module named 'seaborn'
